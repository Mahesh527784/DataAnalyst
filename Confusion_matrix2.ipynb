# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh527784/DataAnalyst/blob/main/Confusion_matrix2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Understanding The DataSet
#
# **PassengerId**: Unique identifier for each passenger.
#
# **Survived:** Target variable (1 = Survived, 0 = Did not survive).
#
# **Pclass:** Passenger class (1st, 2nd, 3rd).
#
# **Name:** Name of the passenger.
#
# **Gender:** Gender of the passenger.
#
# **Age:** Age of the passenger (some missing values).
#
# **SibSp:** Number of siblings/spouses aboard.
#
# **Parch:** Number of parents/children aboard.
#
# **Ticket:** Ticket number.
#
# **Fare:** Ticket fare.
#
# **Cabin:** Cabin number (many missing values).
#
# **Embarked:** Port of embarkation (S, C, Q).

# %% [markdown]
# ### **Business Problem:**
# We want to understand why some passengers survived the Titanic disaster while others did not.
#
# ### **Business Understanding:**
# Survival may depend on factors like age, gender, ticket class, and fare. By analyzing these details, we can find patterns and build a model to predict survival chances.

# %%
import pandas as pd
import numpy as np
Data=pd.read_csv('/content/tested (4).csv')

# %%
Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# **What is a Confusion Matrix?**
# A confusion matrix is a table that compares actual values with predicted values.
#
# It has four main parts:
#
# **True Positive (TP)** – The model correctly predicted survival.
#
# **True Negative (TN)** – The model correctly predicted no survival.
#
# **False Positive (FP)** – The model predicted survival, but the person did not survive.
#
# **False Negative (FN)** – The model predicted no survival, but the person actually survived.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'y_true' contains the true labels and 'y_pred' contains the predicted labels
# Replace these with your actual true and predicted labels

# Example: Assuming you have a 'Survived' column as the target variable
# and a model named 'model'
# y_pred = model.predict(X_test) # Replace X_test with your test data
# y_true = Data['Survived']

# Example data (replace with your actual predictions and true values):
y_true = Data['Survived']
y_pred = np.random.randint(0, 2, size=len(y_true))  # Replace with your model's predictions

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Calculate evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
# Out:
# Accuracy: 0.5119617224880383
# Precision: 0.37735849056603776
# Recall: 0.5263157894736842
# F1-Score: 0.43956043956043955
